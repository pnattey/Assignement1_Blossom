# %%
import pandas as pd
import numpy as np
df =pd.read_csv("free-7-million-company-dataset.zip")
df
# Out:
#         Unnamed: 0                          name             domain  \
# 0          5872184                           ibm            ibm.com
# 1          4425416     tata consultancy services            tcs.com
# 2            21074                     accenture      accenture.com
# 3          2309813                       us army         goarmy.com
# 4          1558607                            ey             ey.com
# ...            ...                           ...                ...
# 204844     4165370  caron transportation systems  carontransport.ca
# 204845     4859186                  ramada hotel  canaltahotels.com
# 204846     5831392       phelan construction ltd      phelans.co.uk
# 204847     4029001                        cebbco         cebbco.com
# 204848     4603252    laboratorio médico polanco      lmpolanco.com
#
#        year founded                             industry size range  \
# 0              1911  information technology and services     10001+
# ...

# %%
df[df['domain'].isnull()].to_csv('/home/fleming/Desktop/blossom/data/Project02/free-7-million-company-dataset.csv')
# Out:
#         Unnamed: 0                          name             domain  \
# 0          5872184                           ibm            ibm.com
# 1          4425416     tata consultancy services            tcs.com
# 2            21074                     accenture      accenture.com
# 3          2309813                       us army         goarmy.com
# 4          1558607                            ey             ey.com
# ...            ...                           ...                ...
# 204844     4165370  caron transportation systems  carontransport.ca
# 204845     4859186                  ramada hotel  canaltahotels.com
# 204846     5831392       phelan construction ltd      phelans.co.uk
# 204847     4029001                        cebbco         cebbco.com
# 204848     4603252    laboratorio médico polanco      lmpolanco.com
#
#        year founded                             industry size range  \
# 0              1911  information technology and services     10001+
# ...

# %%
df[df['domain'].isnull()].to_json( '/home/fleming/Desktop/blossom/data/Project02/free-7-million-company-dataset-json.gzip',compression='gzip')

# %%
df[df['domain'].isnull()].to_parquet( '/home/fleming/Desktop/blossom/data/Project02/free-7-million-company-dataset.parquet')
# Out:
# ---------------------------------------------------------------------------
# ArrowTypeError                            Traceback (most recent call last)
# <ipython-input-134-f6eafc3efdb2> in <module>
# ----> 1 df[df['domain'].isnull()].to_parquet( '/home/fleming/Desktop/blossom/data/Project02/free-7-million-company-dataset.parquet')
#
# ~/Desktop/blossom/env/lib/python3.8/site-packages/pandas/core/frame.py in to_parquet(self, fname, engine, compression, index, partition_cols, **kwargs)
#    2228         from pandas.io.parquet import to_parquet
#    2229
# -> 2230         to_parquet(
#    2231             self,
#    2232             fname,
#
# ~/Desktop/blossom/env/lib/python3.8/site-packages/pandas/io/parquet.py in to_parquet(df, path, engine, compression, index, partition_cols, **kwargs)
#     246     """
#     247     impl = get_engine(engine)
# --> 248     return impl.write(
#     249         df,
#     250         path,
#
# ...

# %%
df = df.replace({np.nan: ''})
df
# Out:
#         Unnamed: 0                          name             domain  \
# 0          5872184                           ibm            ibm.com
# 1          4425416     tata consultancy services            tcs.com
# 2            21074                     accenture      accenture.com
# 3          2309813                       us army         goarmy.com
# 4          1558607                            ey             ey.com
# ...            ...                           ...                ...
# 204844     4165370  caron transportation systems  carontransport.ca
# 204845     4859186                  ramada hotel  canaltahotels.com
# 204846     5831392       phelan construction ltd      phelans.co.uk
# 204847     4029001                        cebbco         cebbco.com
# 204848     4603252    laboratorio médico polanco      lmpolanco.com
#
#        year founded                             industry size range  \
# 0              1911  information technology and services     10001+
# ...

# %%
df[df['domain'].isnull()].to_parquet( '/home/fleming/Desktop/blossom/data/Project02/free-7-million-company-dataset.parquet')
