# %%
#import csv file
import pandas as pd
df = pd.read_csv ('/home/fleming/Desktop/blossom/env/Assignments/project 1/pew.csv')
df
# Out:
#                    religion  <$10k  $10-20k  $20-30k  $30-40k  $40-50k  \
# 0                  Agnostic     27       34       60       81       76
# 1                   Atheist     12       27       37       52       35
# 2                  Buddhist     27       21       30       34       33
# 3                  Catholic    418      617      732      670      638
# 4         Dont know/refused     15       14       15       11       10
# 5         Evangelical Prot     575      869     1064      982      881
# 6                    Hindu       1        9        7        9       11
# 7  Historically Black Prot     228      244      236      238      197
# 8         Jehovahs Witness      20       27       24       24       21
# 9                   Jewish      19       19       25       25       30
#
#    $50-75k
# 0      137
# 1       70
# 2       58
# 3     1116
# 4       35
# 5     1486
# 6       34
# 7      223
# 8       30
# 9       95

# %%
df.transpose()
# Out:
#                  0        1         2         3                  4  \
# religion  Agnostic  Atheist  Buddhist  Catholic  Dont know/refused
# <$10k           27       12        27       418                 15
# $10-20k         34       27        21       617                 14
# $20-30k         60       37        30       732                 15
# $30-40k         81       52        34       670                 11
# $40-50k         76       35        33       638                 10
# $50-75k        137       70        58      1116                 35
#
#                           5       6                         7  \
# religion  Evangelical Prot   Hindu   Historically Black Prot
# <$10k                   575       1                       228
# $10-20k                 869       9                       244
# $20-30k                1064       7                       236
# $30-40k                 982       9                       238
# ...

# %%
df ["Frequncy"] = df["<$10k"] + df["$10-20k"]+ df["$20-30k"]+ df["$30-40k"]+ df["$40-50k"]+ df["$50-75k"]
df
# Out:
#                    religion  <$10k  $10-20k  $20-30k  $30-40k  $40-50k  \
# 0                  Agnostic     27       34       60       81       76
# 1                   Atheist     12       27       37       52       35
# 2                  Buddhist     27       21       30       34       33
# 3                  Catholic    418      617      732      670      638
# 4         Dont know/refused     15       14       15       11       10
# 5         Evangelical Prot     575      869     1064      982      881
# 6                    Hindu       1        9        7        9       11
# 7  Historically Black Prot     228      244      236      238      197
# 8         Jehovahs Witness      20       27       24       24       21
# 9                   Jewish      19       19       25       25       30
#
#    $50-75k  Frequncy
# 0      137       415
# 1       70       233
# 2       58       203
# 3     1116      4191
# 4       35       100
# 5     1486      5857
# 6       34        71
# ...

# %%
df.drop(['<$10k', '$10-20k','$20-30k','$30-40k','$40-50k','$50-75k'], axis = 1)
# Out:
#                    religion  Frequncy
# 0                  Agnostic       415
# 1                   Atheist       233
# 2                  Buddhist       203
# 3                  Catholic      4191
# 4         Dont know/refused       100
# 5         Evangelical Prot       5857
# 6                    Hindu         71
# 7  Historically Black Prot       1366
# 8         Jehovahs Witness        146
# 9                   Jewish        213

# %%
df2 =df.assign(Income_Range= ['<$10k', '$10-20k','$20-30k','$30-40k','$40-50k','$50-75k'])
df2
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-83-b32cb5f3ada5> in <module>
# ----> 1 df2 =df.assign(Income_Range= ['<$10k', '$10-20k','$20-30k','$30-40k','$40-50k','$50-75k'])
#       2 df2
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in assign(self, **kwargs)
#    3667         if PY36:
#    3668             for k, v in kwargs.items():
# -> 3669                 data[k] = com.apply_if_callable(v, data)
#    3670         else:
#    3671             # <= 3.5: do all calculations first...
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3485         else:
#    3486             # set column
# -> 3487             self._set_item(key, value)
#    3488
#    3489     def _setitem_slice(self, key, value):
#
# ...
